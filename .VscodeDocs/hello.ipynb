# %% [markdown]
# # Data Science Tutorial from VsCode Documentation.
# ## site: https://code.visualstudio.com/docs/python/data-science-tutorial

# %% [markdown]
# ## Initialization

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB

data = pd.read_csv('data.csv')

# %% [markdown]
# ## Data Cleaning

# %%
data.replace('?', np.nan, inplace= True)
data = data.astype({"age": np.float64, "fare": np.float64})

# %% [markdown]
# ## Data Visual Analysis

# %%
fig, axs = plt.subplots(ncols=5, figsize=(30,5))

sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])
plt.show()

# %% [markdown]
# ## Correlation calculation

# %%
data.replace({'male': 1, 'female': 0}, inplace=True)

# %%
data.corr().abs()[["survived"]]
# Out:
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055513
# sibsp     0.027825
# parch     0.082660
# fare      0.244265

# %%
data['relatives'] = data.apply (lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
data.corr().abs()[["survived"]]
# Out:
#            survived
# pclass     0.312469
# survived   1.000000
# sex        0.528693
# age        0.055513
# sibsp      0.027825
# parch      0.082660
# fare       0.244265
# relatives  0.201719

# %%
data = data[['sex', 'pclass','age','relatives','fare','survived']].dropna()

# %% [markdown]
# ## Training

# %%
x_train, x_test, y_train, y_test = train_test_split(data[['sex','pclass','age','relatives','fare']], data.survived, test_size=0.2, random_state=0)

# %% [markdown]
# ## Fitting

# %%
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %%
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# ## Prediction

# %%
predict_test = model.predict(X_test)
print(metrics.accuracy_score(y_test, predict_test))
# Out:
# 0.7464114832535885

# %% [markdown]
# ## Using Neural Network for additional Accuracy

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()

# %% [markdown]
# ## Layers

# %%
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu', input_dim = 5))
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %% [markdown]
# ## Code Analysis

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 30
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 66
# Trainable params: 66
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile/Train

# %%
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 3s 3ms/step - loss: 0.6927 - accuracy: 0.5575
# Epoch 2/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6908 - accuracy: 0.5695
# Epoch 3/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6865 - accuracy: 0.5757
# Epoch 4/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6768 - accuracy: 0.5930
# Epoch 5/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6644 - accuracy: 0.6559
# Epoch 6/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6362 - accuracy: 0.7614
# Epoch 7/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6049 - accuracy: 0.7859
# Epoch 8/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5747 - accuracy: 0.7813
# Epoch 9/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5454 - accuracy: 0.7864
# Epoch 10/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5257 - accuracy: 0.7747
# Epoch 11/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5017 - accuracy: 0.7724
# Epoch 12/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4925 - accuracy: 0.7950
# Epoch 13/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4774 - accuracy: 0.7826
# Epoch 14/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4737 - accuracy: 0.7628
# Epoch 15/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4776 - accuracy: 0.7853
# Epoch 16/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4713 - accuracy: 0.7793
# Epoch 17/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4590 - accuracy: 0.7858
# Epoch 18/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4821 - accuracy: 0.7672
# Epoch 19/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4511 - accuracy: 0.7897
# Epoch 20/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4532 - accuracy: 0.8010
# Epoch 21/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4473 - accuracy: 0.7937
# Epoch 22/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4367 - accuracy: 0.8007
# Epoch 23/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4711 - accuracy: 0.7789
# Epoch 24/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4742 - accuracy: 0.7718
# Epoch 25/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4511 - accuracy: 0.7752
# Epoch 26/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4505 - accuracy: 0.7772
# Epoch 27/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4732 - accuracy: 0.7775
# Epoch 28/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4619 - accuracy: 0.7804
# Epoch 29/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4501 - accuracy: 0.8021
# Epoch 30/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4362 - accuracy: 0.7986
# Epoch 31/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4444 - accuracy: 0.7909
# Epoch 32/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4218 - accuracy: 0.8113
# Epoch 33/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4411 - accuracy: 0.7988
# Epoch 34/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4347 - accuracy: 0.7937
# Epoch 35/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4482 - accuracy: 0.7903
# Epoch 36/50
# 27/27 [==============================] - 0s 13ms/step - loss: 0.4486 - accuracy: 0.8000
# Epoch 37/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4515 - accuracy: 0.7913
# Epoch 38/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4512 - accuracy: 0.7954
# Epoch 39/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4295 - accuracy: 0.8168
# Epoch 40/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4346 - accuracy: 0.8174
# Epoch 41/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4464 - accuracy: 0.7903
# Epoch 42/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.4579 - accuracy: 0.7799
# Epoch 43/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4321 - accuracy: 0.8162
# Epoch 44/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4305 - accuracy: 0.8032
# Epoch 45/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4390 - accuracy: 0.8175
# Epoch 46/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4456 - accuracy: 0.7941
# Epoch 47/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4685 - accuracy: 0.7993
# Epoch 48/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4545 - accuracy: 0.7945
# Epoch 49/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4422 - accuracy: 0.8062
# Epoch 50/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4588 - accuracy: 0.7974

# %% [markdown]
# ## Prediction

# %%
y_pred = model.predict_classes(X_test)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.7799043062200957
