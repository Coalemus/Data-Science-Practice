# %%
import numpy as np
import pandas as pd
import matplotlib as plt

dataframe = pd.read_csv("FINAL.csv")
dataframe.describe()
# Out:
#               Age         Sex      Strand  Year Level     Section  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000
# mean    17.542056    1.728972    2.467290    1.719626   44.887850
# std      0.702516    0.445533    1.365695    0.450235   21.887603
# min     16.000000    1.000000    1.000000    1.000000    1.000000
# 25%     17.000000    1.000000    1.000000    1.000000   32.250000
# 50%     18.000000    2.000000    2.000000    2.000000   50.000000
# 75%     18.000000    2.000000    3.000000    2.000000   61.750000
# max     19.000000    2.000000    5.000000    2.000000   79.000000
#
#        Number of Years in AdDU SHS        SBQ1        SBQ2        SBQ3  \
# count                   214.000000  214.000000  214.000000  214.000000
# mean                      1.705607    2.785047    3.317757    3.079439
# std                       0.456838    0.805241    0.614353    0.736855
# min                       1.000000    1.000000    1.000000    1.000000
# ...

# %%
ax = dataframe.plot.hist(legend = None, bins=12, alpha=1.0)

# %%
ax = dataframe.plot(legend = None, kind = 'line')

# %%
ax = dataframe.plot(y = 'Age', kind = 'pie')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-e9dba0815b00> in <module>
# ----> 1 ax = dataframe.plot(kind = 'pie')
#
# C:\Python38\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     898             if isinstance(data, ABCDataFrame):
#     899                 if y is None and kwargs.get("subplots") is False:
# --> 900                     raise ValueError(
#     901                         f"{kind} requires either y column or 'subplots=True'"
#     902                     )
#
# ValueError: pie requires either y column or 'subplots=True'
